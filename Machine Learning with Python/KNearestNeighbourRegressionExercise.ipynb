# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data_raw = pd.read_csv("diabetes.csv")
data = data_raw.filter(["bmi"])
target = data_raw.filter(["response_interest"])

# %%
data.head()
# Out:
#     bmi
# 0  32.1
# 1  21.6
# 2  30.5
# 3  25.3
# 4  23.0

# %%
target.head()
# Out:
#    response_interest
# 0                151
# 1                 75
# 2                141
# 3                206
# 4                135

# %%
knn_reg = KNeighborsRegressor(n_neighbors=3, metric="euclidean")
knn_reg.fit(data, target)
# Out:
# KNeighborsRegressor(metric='euclidean', n_neighbors=3)

# %%
data_test1 = data.iloc[10:11,:]
prediction_test1 = knn_reg.predict(data_test1)
data_test2 = data.iloc[15:16,:]
prediction_test2 = knn_reg.predict(data_test2)
print(f"""Actual data = {data_test1.values[0][0]}
Prediction data = {prediction_test[0][0]}

Actual data = {data_test2.values[0][0]}
Prediction data = {prediction_test2[0][0]}
""")
# Out:
# Actual data = 18.6
# Prediction data = 224.66666666666666
#
# Actual data = 24.7
# Prediction data = 138.66666666666666

# %%
figure, axes = plt.subplots()
axes.scatter(data, target, color="blue", marker=".", linewidth=2, label="Data Points")
axes.set_title("BMI in regards to Disease Progression")
axes.set_xlabel("X: BMI", fontsize=12)
axes.set_ylabel("Y: Disease Progression", fontsize=12)
data_test = np.linspace(20, 40, 100).reshape(-1, 1)
prediction_test = knn_reg.predict(data_test)
axes.plot(data_test, prediction_test, color="red", linewidth=2, label="K-NN Regressor")
axes.legend(fontsize=12)

# %%
prediction_test = knn_reg.predict(data)
mse = mean_squared_error(target, prediction_test)
mae = mean_absolute_error(target, prediction_test)
r2 = r2_score(target, prediction_test)
print(f"""Training set MSE = {mse}
Training set MAE = {mae}
Training set R2 = {r2}
""")
# Out:
# Training set MSE = 3044.490196078431
# Training set MAE = 44.079939668174966
# Training set R2 = 0.48658527964603726
